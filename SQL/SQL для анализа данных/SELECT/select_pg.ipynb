# %%
import pandas as pd
import numpy as np

# %%
from sqlalchemy import create_engine, text
engine = create_engine('postgresql+psycopg2://artoxeig:IeNTfTHOt3TKuBgRXNrXO6IybHwuShdF@hattie.db.elephantsql.com:5432/artoxeig')

# %%
def select(sql):
  with engine.begin() as con:
    query = text(sql)
    return pd.read_sql_query(query, con)

# %%
sql = '''select * from german_credit t'''

# %%
select(sql)
# Out:
#      age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0     33    male    2     own            None             None           3074
# 1     43    male    1     own          little           little           1344
# 2     52    male    2     own      quite rich             None            936
# 3     35  female    3     own          little             None           1393
# 4     28    male    2     own          little             None            776
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   65    male    2    free          little           little           2600
# 996   30    male    3     own          little         moderate           4455
# 997   33    male    2     own          little         moderate           6403
# 998   29  female    2     own            None             None           5003
# 999   44    male    2     own        moderate         moderate           1804
#
# ...

# %%
sql = ''' select t.* from german_credit as t
        where t.credit_amount > 2000'''

# %%
select(sql)
# Out:
#      age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0     33    male    2     own            None             None           3074
# 1     26    male    2     own          little           little           4370
# 2     27  female    2     own          little           little           3123
# 3     35    male    2    free          little           little           3386
# 4     35    male    2     own          little         moderate           2576
# ..   ...     ...  ...     ...             ...              ...            ...
# 563   60  female    3    free        moderate         moderate          14782
# 564   65    male    2    free          little           little           2600
# 565   30    male    3     own          little         moderate           4455
# 566   33    male    2     own          little         moderate           6403
# 567   29  female    2     own            None             None           5003
#
# ...

# %%
new_tab = select(sql)

# %%
new_tab.to_sql('greater_c_2000', engine, index=False, if_exists='replace')
# Out:
# 568

# %%
sql = '''
        Drop table if exists greater_2000;
        create table greater_2000 as
        select * from german_credit as t
        where t.credit_amount > 2000
        '''

# %%
# created new table in postgres
engine.connect().execute(text(sql))

# %%
sql = '''select t.sex, substr(t.sex, 1,1) from greater_c_2000 as t'''

# %%
select(sql)
# Out:
#         sex substr
# 0      male      m
# 1      male      m
# 2    female      f
# 3      male      m
# 4      male      m
# ..      ...    ...
# 563  female      f
# 564    male      m
# 565    male      m
# 566    male      m
# 567  female      f
#
# [568 rows x 2 columns]

# %%
select(sql)
# Out:
#         sex substr
# 0      male      m
# 1      male      m
# 2    female      f
# 3      male      m
# 4      male      m
# ..      ...    ...
# 563  female      f
# 564    male      m
# 565    male      m
# 566    male      m
# 567  female      f
#
# [568 rows x 2 columns]
